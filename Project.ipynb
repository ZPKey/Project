# %%
with open("999reviews.csv",'r', encoding='utf8') as file:
    nines = file.read()
    nines = nines.replace('\n', ' ; ')
    nines = nines.split(' ')

# %%
 dataset
# Out:
# ['剧情神作，就是第二部冗长的过场动画让人感到烦躁，而且3d建模也是一坨，还不如沿用999的建模呢',
#  ';',
#  '"The',
#  'story',
#  'in',
#  'both',
#  'games',
#  'are',
#  'very',
#  'good.',
#  ';',
#  'I',
#  'prefer',
#  'the',
#  'story',
#  'in',
#  'VLR,',
#  'but',
#  'the',
#  'gameplay',
#  'in',
#  'VLR',
#  'is',
#  'more',
#  'troublesome',
#  'than',
#  '999.',
#  ';',
#  'Highly',
#  'recommended',
#  'mystery',
#  'game.',
#  ';',
#  'Uchikoshi',
#  'did',
#  'a',
#  'very',
#  'good',
#  'job',
#  'in',
#  'these',
#  'games."',
#  ';',
#  'best',
#  'suspense',
#  'zero',
#  'escape',
#  'series',
#  'than',
#  'ztd',
#  ';',
#  '"999全通',
#  '留个评论',
#  '',
#  '整体可以给到7',
#  'or',
#  '8/10',
#  '的总分',
#  '还是挺上头的',
#  ';',
#  '[spoiler]santa和紫永远处在一道门的设计确实很好的掩盖了真相',
#  '可以说是这部最有意思的地方[/spoiler]',
#  ';',
#  '虽然核心诡计确实不如[spoiler]ever17',
#  '',
#  '并且对于先玩完ever17的我',
#  '真结局也有一种既视感[/spoiler]',
#  '',
#  ';',
#  '最终理论的解释',
#  '也确实有点强差人意...',
#  '属于是也算说得通的级别',
#  '',
#  ';',
#  '"',
#  ';',
#  '"Okej',
#  'no',
# ...

# %%
"puzzle" in dataset
# Out:
# True

# %%
"platformer" in dataset
# Out:
# False
